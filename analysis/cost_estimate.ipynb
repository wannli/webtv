# %%
import pandas as pd
import requests
from urllib.parse import quote
from joblib import Memory
import tiktoken

# %%
df = pd.read_json("video-metadata.json")
df["hours"] = pd.to_timedelta(df["duration"]).dt.total_seconds() / 3600
pd.options.display.float_format = "{:.2f}".format

# %%
stats = (
    df.groupby(["date", "body"], dropna=False)
    .agg({"hours": "sum"})
    .groupby("body", dropna=False)
    .agg({"hours": "mean"})
)
stats = stats.rename(columns={"hours": "hours_per_day"})
stats
# Out:
#                              hours_per_day
# body
# Economic and Social Council          12.18
# Fifth Committee                       1.32
# First Committee                       3.37
# Fourth Committee                      2.59
# General Assembly                     10.52
# Second Committee                      3.78
# Security Council                      4.90
# Sixth Committee                       3.88
# Third Committee                       4.54
# Trusteeship Council                   0.80
# NaN                                  29.19

# %%
stats["assemblyai_cost_per_day"] = stats["hours_per_day"] * 0.15
stats["assemblyai_cost_per_year"] = stats["assemblyai_cost_per_day"] * 365
stats.loc["Total"] = stats.sum(numeric_only=True)
stats
# Out:
#                              hours_per_day  assemblyai_cost_day  \
# body
# Economic and Social Council          12.18                 1.83
# Fifth Committee                       1.32                 0.20
# First Committee                       3.37                 0.51
# Fourth Committee                      2.59                 0.39
# General Assembly                     10.52                 1.58
# Second Committee                      3.78                 0.57
# Security Council                      4.90                 0.74
# Sixth Committee                       3.88                 0.58
# Third Committee                       4.54                 0.68
# Trusteeship Council                   0.80                 0.12
# NaN                                  29.19                 4.38
# Total                                77.08                11.56
#
#                              assemblyai_cost_year
# body
# Economic and Social Council                667.12
# Fifth Committee                             72.29
# First Committee                            184.67
# Fourth Committee                           141.88
# General Assembly                           575.87
# Second Committee                           206.81
# Security Council                           268.52
# Sixth Committee                            212.51
# Third Committee                            248.66
# Trusteeship Council                         43.56
# NaN                                       1598.24
# Total                                     4220.14

# %%
memory = Memory(location=".cache")


@memory.cache
def fetch_text(id):
    data = requests.get("https://webtv.unfck.org/json/" + quote(id, safe="")).json()
    transcript = data["transcript"]["data"]
    text = "\n".join(
        [
            sent["text"]
            for statement in transcript
            for para in statement["paragraphs"]
            for sent in para["sentences"]
        ]
    )
    return text

# %%
encoding = tiktoken.encoding_for_model('gpt-5')

# %%
transcripts = df[df["hasTranscript"]].iloc[:10]
transcripts["text"] = transcripts["id"].apply(fetch_text)
transcripts["n_tokens"] = transcripts["text"].apply(encoding.encode).apply(len)
tokens_per_hour = float(transcripts["n_tokens"].sum() / transcripts["hours"].sum())
tokens_per_hour
# Out:
# 7851.193626066534

# %%
def cost(n_tokens):
    cost_input = n_tokens * 1.750 / 1_000_000
    cost_output = n_tokens * 14 / 1_000_000
    cost = cost_input + 2 * cost_output # assuming substantive token use for reasoning
    return cost

stats["n_tokens"] = stats["hours_per_day"] * tokens_per_hour
stats["openai_cost_per_day"] = stats["n_tokens"].apply(cost) * 2 # 2 stages: speaker identification + topic identification
stats["openai_cost_per_year"] = stats["openai_cost_per_day"] * 365
stats
# Out:
#                              hours_per_day  assemblyai_cost_day  \
# body
# Economic and Social Council          12.18                 1.83
# Fifth Committee                       1.32                 0.20
# First Committee                       3.37                 0.51
# Fourth Committee                      2.59                 0.39
# General Assembly                     10.52                 1.58
# Second Committee                      3.78                 0.57
# Security Council                      4.90                 0.74
# Sixth Committee                       3.88                 0.58
# Third Committee                       4.54                 0.68
# Trusteeship Council                   0.80                 0.12
# NaN                                  29.19                 4.38
# Total                                77.08                11.56
#
#                              assemblyai_cost_year  n_tokens  \
# body
# Economic and Social Council                667.12  95665.72
# Fifth Committee                             72.29  10366.18
# First Committee                            184.67  26482.19
# Fourth Committee                           141.88  20346.25
# General Assembly                           575.87  82579.72
# Second Committee                           206.81  29656.79
# Security Council                           268.52  38506.36
# Sixth Committee                            212.51  30474.67
# Third Committee                            248.66  35658.71
# Trusteeship Council                         43.56   6246.06
# NaN                                       1598.24 229188.49
# Total                                     4220.14 605171.13
#
#                              openai_cost_per_day  openai_cost_per_year
# body
# Economic and Social Council                 5.69               2077.62
# Fifth Committee                             0.62                225.13
# First Committee                             1.58                575.13
# Fourth Committee                            1.21                441.87
# General Assembly                            4.91               1793.42
# Second Committee                            1.76                644.07
# Security Council                            2.29                836.26
# Sixth Committee                             1.81                661.83
# Third Committee                             2.12                774.42
# Trusteeship Council                         0.37                135.65
# NaN                                        13.64               4977.40
# Total                                      36.01              13142.80
